# %%
from show_dev_day import dayplot

# %%
#for day in ['0106','0107','0108','0109','0110']:
for day in ['0108','0109','0110', '0111','0112']:
    print(day)
    dayplot(day=day, device = 'str88_dev78', string='36')
# Out:
# 0108
# /data/user/leidensc/simulation/show_dev_day.py:100: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   cbar.ax.set_yticklabels(ticklabs, fontsize=14)
# 0109
# /data/user/leidensc/simulation/show_dev_day.py:100: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   cbar.ax.set_yticklabels(ticklabs, fontsize=14)
# 0110
# /data/user/leidensc/simulation/show_dev_day.py:100: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   cbar.ax.set_yticklabels(ticklabs, fontsize=14)
# 0111
# /data/user/leidensc/simulation/show_dev_day.py:100: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   cbar.ax.set_yticklabels(ticklabs, fontsize=14)
# 0112
# ...

# %%
#for day in ['0106','0107','0108','0109','0110']:
for device in ['str87_dev8','str88_dev6','str88_dev78']:
    print(device)
    dayplot(day='0112', device = device, string='36')
# Out:
# str87_dev8
# /data/user/leidensc/simulation/show_dev_day.py:100: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   cbar.ax.set_yticklabels(ticklabs, fontsize=14)
# str88_dev6
# /data/user/leidensc/simulation/show_dev_day.py:100: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   cbar.ax.set_yticklabels(ticklabs, fontsize=14)
# str88_dev78
# /data/user/leidensc/simulation/show_dev_day.py:100: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   cbar.ax.set_yticklabels(ticklabs, fontsize=14)
